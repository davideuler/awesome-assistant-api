# %% [markdown]
# # A demo for visual assistant

# %%
# !pip install openai requests
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.9 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
# setup OpenAI api_key
import getpass
api_key = getpass.getpass("Enter the OpenAI API Key(which starts with sk-): ")
# Out:
# Enter the OpenAI API Key(which starts with sk-): ··········

# %%
from openai import OpenAI

client = OpenAI(api_key=api_key)

response = client.chat.completions.create(
    model="gpt-4-vision-preview",
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "What’s in this image? "},
                {
                    "type": "image_url",
                    "image_url": {
                        #"url": "https://upload.wikimedia.org/wikipedia/commons/thumb/d/dd/Gfp-wisconsin-madison-the-nature-boardwalk.jpg/2560px-Gfp-wisconsin-madison-the-nature-boardwalk.jpg",
                        "url": "https://raw.githubusercontent.com/davideuler/awesome-assistant-api/main/images/512x512.jpg"
                    },
                },
            ],
        }
    ],
    max_tokens=300,
)

print(response.choices[0])
# Out:
# Choice(finish_reason=None, index=0, message=ChatCompletionMessage(content="The image shows a blue butterfly with black spots on its wings, perched on a flower. The butterfly's wings are slightly open, showcasing the blue color on the upper side of its wings. The background is a smooth, out-of-focus green, which highlights the subject. The flower appears to be a bud, not fully blossomed, and the plant it's on may be a variety found in a garden or a wild habitat. The scene captures a tranquil moment in nature, emphasizing the delicate interaction between the butterfly and the plant.", role='assistant', function_call=None, tool_calls=None), finish_details={'type': 'stop', 'stop': '<|fim_suffix|>'})

# %%
response
# Out:
# ChatCompletion(id='chatcmpl-8JFvyPtByI2TcuBbllAs1ic05Xge9', choices=[Choice(finish_reason=None, index=0, message=ChatCompletionMessage(content='The image depicts a long wooden boardwalk leading through a lush green meadow with grasses and shrubs under a blue sky scattered with clouds. The setting appears serene and is likely a nature reserve or park designed for walking and enjoying the outdoors.\n\nNow, I will proceed to edit the image by adding a sun in the top left corner and adjusting the lighting to simulate sunshine flashing. Please wait a moment while I work on this.', role='assistant', function_call=None, tool_calls=None), finish_details={'type': 'stop', 'stop': '<|fim_suffix|>'})], created=1699600174, model='gpt-4-1106-vision-preview', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=86, prompt_tokens=1137, total_tokens=1223))

# %% [markdown]
# For the chat completion API, we could not get the result of the modified image. Let's try the assistant API
