# %% [markdown]
# # A demo for chatgpt assistant api
# Interactive CLI for a personalized Python tutoring experience.
# Real-time feedback and exercise suggestion based on user input.
# Use of OpenAI's powerful Assistant API to simulate a Python tutor.
#
# https://github.com/BenderScript/pytutor

# %%
# !pip install openai requests colorama python-dotenv
# Out:
# Collecting openai
#   Downloading openai-1.2.3-py3-none-any.whl (220 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.3/220.3 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.31.0)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.25.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.10.13)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.1)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.10/dist-packages (from openai) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2023.7.22)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4,>=3.5.0->openai) (1.1.3)
# Collecting httpcore (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.1 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: python-dotenv, h11, colorama, httpcore, httpx, openai
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# Successfully installed colorama-0.4.6 h11-0.14.0 httpcore-1.0.2 httpx-0.25.1 openai-1.2.3 python-dotenv-1.0.0

# %%
# setup OpenAI api_key
import getpass
api_key = getpass.getpass("Enter the OpenAI API Key(which starts with sk-): ")
# Out:
# Enter the OpenAI API Key(which starts with sk-): ··········

# %% [markdown]
# Run code

# %%
import os
import time

import openai
from dotenv import load_dotenv
from colorama import Fore, Style


def check_run(client, thread_id, run_id):
    while True:
        # Refresh the run object to get the latest status
        run = client.beta.threads.runs.retrieve(
            thread_id=thread_id,
            run_id=run_id
        )

        if run.status == "completed":
            print(f"{Fore.GREEN} Run is completed.{Style.RESET_ALL}")
            break
        elif run.status == "expired":
            print(f"{Fore.RED}Run is expired.{Style.RESET_ALL}")
            break
        else:
            print(f"{Fore.YELLOW} OpenAI: Run is not yet completed. Waiting...{run.status} {Style.RESET_ALL}")
            time.sleep(3)  # Wait for 1 second before checking again


def chat_loop(client, assistant, thread):
    while True:
        # Input from user

        user_input = input(f"{Fore.CYAN} User: ")
        print(Style.RESET_ALL)
        if user_input == "quit":
            break

        message = client.beta.threads.messages.create(
            thread_id=thread.id,
            role="user",
            content=user_input
        )

        run = client.beta.threads.runs.create(
            thread_id=thread.id,
            assistant_id=assistant.id,
        )

        check_run(client, thread.id, run.id)

        # Get the latest messages from the thread
        messages = client.beta.threads.messages.list(
            thread_id=thread.id
        )

        # Get the latest message from the user
        user_message = messages.data[1].content[0].text.value

        # Get the latest message from the assistant
        assistant_message = messages.data[0].content[0].text.value

        # Print the latest message from the user
        # print(f"{Fore.CYAN} User: {user_message} {Style.RESET_ALL}")

        # Print the latest message from the assistant
        print(f"{Fore.BLUE} Assistant: {assistant_message} {Style.RESET_ALL}")


def main():
    load_dotenv(override=True, dotenv_path=".env")  # take environment variables from .env.
    openai.api_key = os.getenv("OPENAI_API_KEY")

    client = openai.Client(api_key=api_key)

    print(f"{Fore.MAGENTA} Welcome to the Python Tutor. I am here to help you learn python...{Style.RESET_ALL}\n")

    assistant = client.beta.assistants.create(
        name="Python Tutor",
        instructions="You are a personal Python tutor. You are teaching a high-school student learn Python. Track the "
                     "user progress and assign new exercises as the user progresses.",
        tools=[{"type": "code_interpreter"}],
        model="gpt-4-1106-preview"
    )

    thread = client.beta.threads.create()

    chat_loop(client, assistant, thread)


if __name__ == "__main__":
    main()
# Out:
#  Welcome to the Python Tutor. I am here to help you learn python...
#
#
#  OpenAI: Run is not yet completed. Waiting...queued
#  Run is completed.
#  Assistant: Hello! It's great to see you're interested in learning Python. As a personal tutor, I'm here to guide you through the process. Whether you're just starting out or looking to improve your skills, I'll tailor our sessions to your needs. What is your current level of experience with Python, and what would you like to focus on today?
#
#  OpenAI: Run is not yet completed. Waiting...queued
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  Run is completed.
#  Assistant: To program professionally in Python, you'll want to learn a wide range of concepts and skills, and practice them until you're comfortable. Here's a list that outlines a typical journey to becoming proficient in Python:
#
# ### Basics
# 1. **Python Syntax and Semantics**: Variables, operators, and basic data types (int, float, string, boolean).
# 2. **Control Structures**: Conditional statements (if, elif, else), loops (for, while).
# 3. **Functions**: Definition, parameters, return values, scope, lambda expressions.
# 4. **Data Structures**: Lists, tuples, sets, dictionaries, and how to iterate over them.
# 5. **String Manipulation**: Basic string methods, formatting, and regular expressions.
# 6. **File I/O**: Opening, reading, writing, and closing files.
#
# ### Intermediate
# 7. **Error Handling**: Try, except, finally clauses, raising exceptions.
# 8. **Modules and Packages**: Importing standard modules, using pip to install packages, creating your own modules.
# 9. **Object-Oriented Programming**: Classes, objects, inheritance, encapsulation, polymorphism.
# 10. **Functional Programming**: Understanding of map, filter, reduce, comprehensions.
#
# ### Advanced
# 11. **Advanced Data Structures**: Collections module, understanding of stack, queue, tree, graph, heap etc.
# 12. **Iterators and Generators**: Creating and using iterators, generator functions, generator expressions.
# 13. **Decorators**: Understanding and writing decorators, nesting decorators.
# 14. **Context Managers**: With statement, creating your own context managers.
#
# ### Software Development
# 15. **Version Control**: Using tools like git, understanding of version control concepts.
# 16. **Virtual Environments**: Creating and managing isolated Python environments with venv or virtualenv.
# 17. **Testing**: Writing unit tests using frameworks like unittest, pytest.
# 18. **Debugging**: Techniques and tools for debugging your code.
# 19. **Profiling & Optimization**: Identifying performance bottlenecks, optimizing code.
#
# ### Web Development
# 20. **Web Frameworks**: Learning frameworks like Flask, Django for back-end development.
# 21. **RESTful API Development**: Understanding HTTP methods, status codes, designing RESTful services.
# 22. **Front-end Technologies**: HTML, CSS, JavaScript (optional but useful for full-stack development).
# 23. **Databases**: SQL databases (like SQLite, MySQL, PostgreSQL), ORMs, possibly NoSQL databases (like MongoDB).
#
# ### Data Science (if you're interested)
# 24. **Data Analysis**: Libraries like pandas, NumPy.
# 25. **Data Visualization**: Libraries like matplotlib, seaborn, Plotly.
# 26. **Machine Learning**: Scikit-learn for basic ML tasks, TensorFlow or PyTorch for deep learning.
#
# ### Deployment
# 27. **Containers**: Docker basics, creating and deploying containerized applications.
# 28. **Cloud Services**: Understanding and using cloud platforms such as AWS, GCP, or Azure.
# 29. **Continuous Integration/Continuous Deployment (CI/CD)**: Tools like Jenkins, Travis CI, GitHub Actions.
#
# ### Best Practices
# 30. **Code Readability**: Writing clean, readable, and maintainable code.
# 31. **Design Patterns**: Learning customary software design patterns.
# 32. **Documentation**: Writing useful comments and creating documentation.
# 33. **Security**: Basic security best practices in software development.
#
# ### Soft Skills
# 34. **Problem-Solving**: Developing analytical skills for solving complex problems.
# 35. **Collaboration**: Working effectively in teams, understanding Agile methodologies.
# 36. **Communication**: Writing well-articulated bug reports, emails, and documentation.
#
# Remember, the path to learning Python or any programming language is not strictly linear and often involves revisiting topics with a deeper understanding as you progress. Coding often and working on real projects is as important as studying these concepts.
#
# Where would you like to start, or what specific areas are you interested in?
#
#  OpenAI: Run is not yet completed. Waiting...queued
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  Run is completed.
#  Assistant: Starting with front-end technologies is a bit unconventional considering Python is primarily a back-end language. However, having an understanding of front-end development can be very beneficial when becoming a full-stack developer, or when you need to create applications that have a user interface (UI).
#
# In front-end development, there are three core technologies you'll want to become familiar with:
#
# 1. **HTML (HyperText Markup Language)**: This is the standard markup language for creating web pages. It represents the structure of web content.
#
# 2. **CSS (Cascading Style Sheets)**: CSS is used for describing the presentation of a document written in HTML. It allows you to style the content, such as setting fonts, colors, and positioning.
#
# 3. **JavaScript**: It's a scripting language that enables interactive web pages. While it is not Python, it's an essential part of web development. With JavaScript, you can manipulate the DOM (Document Object Model), control the browser, and modify the content shown to the user.
#
# Since these technologies are not part of Python, my role teaching Python is limited here. However, I can help you understand the basics of each and how they interact with each other. Once you get a grip on these, you can later integrate them with Python web frameworks like Flask or Django.
#
# Would you like to proceed with an introduction to these front-end technologies, or would you prefer to start with Python and later on look at how to integrate Python with front-end development?
#
#  OpenAI: Run is not yet completed. Waiting...queued
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  OpenAI: Run is not yet completed. Waiting...in_progress
#  Run is completed.
#  Assistant: While JavaScript is the language of choice for the front-end and Python is typically used on the server-side (back-end), they can certainly be integrated to create full-stack applications. Here's how the two can work together and various methods for integrating them:
#
# ### 1. Python Web Frameworks and JavaScript:
# Python web frameworks, such as Flask and Django, allow you to serve HTML pages that can include JavaScript code. The usual flow of integration is as follows:
#
# - The **Python server** runs the back-end logic, handles database interactions, and processes user requests sent from the front-end (usually through HTTP requests).
# - **HTML templates** can include JavaScript code and are rendered on the server side (using, for example, Jinja2 templating in Flask).
# - When a **web page** is served to the client (user's web browser), any included JavaScript becomes active and can dynamically change the web page without the need to reload it from the server (using AJAX or Fetch API).
# - **JavaScript** makes requests to the Python server (via RESTful APIs or GraphQL) to send or retrieve data. This can be done without page refreshes to provide a seamless user experience, commonly referred to as "AJAX" (Asynchronous JavaScript and XML) calls.
#
# ### 2. RESTful APIs with Python:
# Creating a RESTful API in Python is a common way to allow a front-end coded in JavaScript or any other language to communicate with the Python application.
#
# - Develop a back-end API using a Python framework. Frameworks like Flask and Django have extensions or built-in features specifically for building APIs (Flask-RESTful, Django REST framework).
# - The front-end will use JavaScript to send HTTP requests to interact with your API. It can create, read, update, and delete resources using API endpoints.
#
# ### 3. WebSockets:
# For real-time communication between the client and server, WebSockets can be used.
#
# - Python packages like `socket.io` (for Flask) and Channels (for Django) can handle WebSocket connections in your back-end.
# - JavaScript on the client side can create and manage WebSocket connections to facilitate real-time data transfer.
#
# ### 4. Server-Side Rendering (SSR) vs Client-Side Rendering (CSR):
# Python and JavaScript can also work together depending on where the rendering of content occurs.
#
# - **SSR**: With SSR, pages are rendered on the server, often with template engines. Python handles the data and template before sending a completed HTML page to the client.
# - **CSR**: With CSR, the server sends a bare-bones HTML page along with JavaScript that renders content directly in the browser by making API calls to the server to fetch the data.
#
# ### 5. Microservices:
# You can separate the front-end and back-end into distinct services.
#
# - The front-end application can be a standalone JavaScript application (using frameworks like React, Angular, or Vue.js) that communicates with a Python-based back-end microservice.
# - The back-end microservice can be developed using Python and its frameworks, exposing APIs that the JavaScript front-end will consume.
#
# ### 6. Deployment:
# To serve both the front-end and back-end code, you can:
#
# - Deploy Python and JavaScript parts separately, with a static site host for the JavaScript front-end (like Netlify or GitHub Pages) and a cloud service for the Python back-end (like Heroku, AWS, or GCP).
# - Bundle them together, with the front-end as static files served by the Python application upon request.
#
# Understanding how to integrate Python with a front-end will ultimately depend on the architecture of your application and the requirements of your project. Would you like to explore building a simple web application using Python and integrating it with a basic JavaScript front-end to grasp these concepts better?
#  User: quit

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落
